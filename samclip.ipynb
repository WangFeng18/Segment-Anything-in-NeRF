# %%
from samnerf.langsam import LanguageSAM
import matplotlib.pyplot as plt
LangSAM = LanguageSAM()
LangSAM.set_image("/data/machine/nerfstudio/test.jpg")
mskimg = LangSAM.get_mask_by_prompt(prompt=["a laughing woman"], point_num=1, threshold=0.5)
plt.axis("off")
plt.tight_layout()
plt.imshow(mskimg)
# Out:
# clip cost: 0.011635780334472656
# cond cost: 0.023942947387695312
# clipseg cost: 0.0046083927154541016
# clip cost: 0.011633872985839844
# cond cost: 0.02354717254638672
# clipseg cost: 0.0040972232818603516

# %%
from IPython.display import display, HTML
display(HTML("<style>div.output_scroll { height: 80em; }</style>"))
#display(HTML("<style>.container { width:100% !important; height: 800px !important;}</style>"))
LangSAM.launch_gradio()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 from IPython.display import display, HTML
#       2 import IPython
# ----> 3 IPython.OutputArea.auto_scroll_threshold = 9999;
#       4 display(HTML("<style>div.output_scroll { height: 80em; }</style>"))
#       5 #display(HTML("<style>.container { width:100% !important; height: 800px !important;}</style>"))
#
# AttributeError: module 'IPython' has no attribute 'OutputArea'
