# %%
from samnerf.langsam import LanguageSAM
import matplotlib.pyplot as plt
LangSAM = LanguageSAM()
LangSAM.set_image("/data/machine/samclip/samclip.jpg")
mskimg = LangSAM.get_mask_by_prompt(prompt=["a laughing woman"], point_num=1, threshold=0.5)
plt.axis("off")
plt.tight_layout()
plt.imshow(mskimg)

# %%
from IPython.display import display, HTML
display(HTML("<style>div.output_scroll { height: 80em; }</style>"))
#display(HTML("<style>.container { width:100% !important; height: 800px !important;}</style>"))
LangSAM.launch_gradio()
# Out:
# <style>div.output_scroll { height: 80em; }</style>
# creating gradio interface
# /data/machine/anaconda3/envs/nerfstudio/lib/python3.8/site-packages/gradio/components.py:167: UserWarning: Unknown style parameter: width
#   warnings.warn(f"Unknown style parameter: {key}")
# /data/machine/anaconda3/envs/nerfstudio/lib/python3.8/site-packages/gradio/deprecation.py:43: UserWarning: You have unused kwarg parameters in Slider, please remove them: {'default': 0.5}
#   warnings.warn(
# /data/machine/anaconda3/envs/nerfstudio/lib/python3.8/site-packages/gradio/deprecation.py:43: UserWarning: You have unused kwarg parameters in Slider, please remove them: {'default': 5}
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://7c312927d2ab762cd6.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://7c312927d2ab762cd6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
